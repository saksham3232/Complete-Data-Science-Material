# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
X,y=make_circles(n_samples=500,factor=0.5,noise=0.05)

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
lof=LocalOutlierFactor(n_neighbors=20,metric='euclidean',contamination=0.1)
y_pred=lof.fit_predict(X)

# %%
outliers=X[y_pred==-1]

# %%
outliers
# Out:
# array([[ 0.4670772 , -0.09645829],
#        [ 0.48636744, -0.10177446],
#        [ 0.62001212,  0.12970062],
#        [ 0.21668161, -0.41399496],
#        [ 0.19258506, -0.33346428],
#        [ 0.00419339,  0.67529214],
#        [ 0.51572392, -0.07052643],
#        [ 0.56197814, -0.08974037],
#        [-0.10154348, -0.45213413],
#        [-0.56672378, -0.19252745],
#        [-0.10211934, -0.5556545 ],
#        [ 0.07924567, -1.08884575],
#        [ 0.55539923, -0.16080743],
#        [ 0.18699913, -0.43893737],
#        [ 0.14780414, -1.05086263],
#        [-0.11154889, -0.55564779],
#        [-0.11744698, -0.47197722],
#        [-0.27095342, -0.53452485],
#        [-0.04468311,  0.55402007],
#        [-0.4861065 ,  0.40052155],
#        [ 0.20460866, -0.42046747],
#        [-0.23759544,  0.83555552],
#        [ 0.26078806,  0.54113073],
#        [ 0.4177552 ,  0.4427207 ],
#        [-0.52816987,  0.27558515],
#        [-0.07984827, -0.45305518],
#        [-0.74670064,  0.50648987],
#        [ 0.34850246,  0.43502825],
#        [ 0.48646469, -0.0916695 ],
#        [-0.34777382, -0.51602695],
#        [ 0.48860319, -0.17012228],
#        [ 0.30421774, -0.46793075],
#        [ 0.40914725, -0.15339567],
#        [ 0.56345947, -0.04134449],
#        [ 0.90647354,  0.08643947],
#        [ 0.24664267, -0.52646694],
#        [ 0.44360956,  0.38744952],
#        [-0.19946534,  1.09943146],
#        [ 0.1617298 , -0.42117177],
#        [-0.09629244, -0.42581648],
#        [ 0.21120107, -1.02335175],
#        [-0.15861802, -0.36043766],
#        [-0.57420217, -0.67720887],
#        [ 0.26379499, -0.43804159],
#        [-0.21318431, -0.46795893],
#        [ 0.45223907, -0.1650845 ],
#        [ 0.16820105, -0.47073135],
#        [ 0.49349462, -0.2122757 ],
#        [ 0.28699115, -0.33830807],
#        [-0.13387953,  0.57057734]])

# %%
plt.scatter(X[:,0],X[:,1])
plt.scatter(outliers[:,0],outliers[:,1],color='r')
plt.title('Local Outlier Factor(Anomaly Detection)')
# Out:
# Text(0.5, 1.0, 'Local Outlier Factor(Anomaly Detection)')
