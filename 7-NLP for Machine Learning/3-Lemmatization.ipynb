# %% [markdown]
# ## Wordnet Lemmatizer
# Lemmatization technique is like stemming. The output we will get after lemmatization is called ‘lemma’, which is a root word rather than root stem, the output of stemming. After lemmatization, we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This class uses morphy() function to the WordNet CorpusReader class to find a lemma. Let us understand it with an example −

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\saksh\AppData\Roaming\nltk_data...
# True

# %%
'''
POS
noun-n
verb-v
adjective-a
adverb-r
'''
lemmatizer.lemmatize('going', pos='v')
# Out:
# 'go'

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
for word in words:
    print(f"{word} -> {lemmatizer.lemmatize(word, pos='v')} (verb), {lemmatizer.lemmatize(word, pos='n')} (noun), {lemmatizer.lemmatize(word, pos='a')} (adjective), {lemmatizer.lemmatize(word, pos='r')} (adverb)")
# Out:
# eating -> eat (verb), eating (noun), eating (adjective), eating (adverb)
# eats -> eat (verb), eats (noun), eats (adjective), eats (adverb)
# eaten -> eat (verb), eaten (noun), eaten (adjective), eaten (adverb)
# writing -> write (verb), writing (noun), writing (adjective), writing (adverb)
# writes -> write (verb), writes (noun), writes (adjective), writes (adverb)
# programming -> program (verb), programming (noun), programming (adjective), programming (adverb)
# programs -> program (verb), program (noun), programs (adjective), programs (adverb)
# history -> history (verb), history (noun), history (adjective), history (adverb)
# finally -> finally (verb), finally (noun), finally (adjective), finally (adverb)
# finalized -> finalize (verb), finalized (noun), finalized (adjective), finalized (adverb)

# %%
lemmatizer.lemmatize('goes',pos='v')
# Out:
# 'go'

# %%
lemmatizer.lemmatize('fairly', pos='a'), lemmatizer.lemmatize('sportingly', pos='a')
# Out:
# ('fairly', 'sportingly')
