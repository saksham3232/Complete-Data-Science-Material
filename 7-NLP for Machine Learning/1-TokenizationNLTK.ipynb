# %% [markdown]
# ## Tokenization

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\saksh\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\saksh\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\saksh\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\saksh\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\saksh\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\saksh\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)

# %%
corpus="Hello, world! This is a test corpus. It contains several sentences. Let's see how it works."

# %%
print(corpus)
# Out:
# Hello, world! This is a test corpus. It contains several sentences. Let's see how it works.

# %%
## Tokenization
## Sentence -> Paragraph
import nltk
from nltk.tokenize import sent_tokenize

# Download the required Punkt tokenizer models
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\saksh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents=sent_tokenize(corpus)

# %%
documents
# Out:
# ['Hello, world!',
#  'This is a test corpus.',
#  'It contains several sentences.',
#  "Let's see how it works."]

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello, world!
# This is a test corpus.
# It contains several sentences.
# Let's see how it works.

# %%
## Tokenization
## Paragraph -> Words
## Sentence -> Words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'world',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'corpus',
#  '.',
#  'It',
#  'contains',
#  'several',
#  'sentences',
#  '.',
#  'Let',
#  "'s",
#  'see',
#  'how',
#  'it',
#  'works',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', ',', 'world', '!']
# ['This', 'is', 'a', 'test', 'corpus', '.']
# ['It', 'contains', 'several', 'sentences', '.']
# ['Let', "'s", 'see', 'how', 'it', 'works', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'world',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'corpus',
#  '.',
#  'It',
#  'contains',
#  'several',
#  'sentences',
#  '.',
#  'Let',
#  "'",
#  's',
#  'see',
#  'how',
#  'it',
#  'works',
#  '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer

# %%
tokenizer=TreebankWordDetokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# "H e l l o,   w o r l d!   T h i s   i s   a   t e s t   c o r p u s .   I t   c o n t a i n s   s e v e r a l   s e n t e n c e s .   L e t' s   s e e   h o w   i t   w o r k s."
